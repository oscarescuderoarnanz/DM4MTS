# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
# %matplotlib notebook
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.cluster import KMeans
from scipy.cluster import hierarchy
import scipy.cluster.hierarchy as shc

import scipy.io as sio
from sklearn import manifold

from mpl_toolkits.mplot3d import Axes3D

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
def plotTSNE(X,y, name, value):
    red = y == 0
    green = y == 1

    plt.figure(figsize=(8,8))
    tsne = manifold.TSNE(n_components=2, init='random', perplexity=value, random_state=0)
    Y = tsne.fit_transform(X)
    principalDf = pd.DataFrame(data = Y, columns = ['pca1', 'pca2'])
    
    class_0 = np.where(y == 0)
    class_1 = np.where(y == 1)
    
    plt.scatter(Y[class_1, 0], Y[class_1, 1], marker='x', s=50, linewidths=2, color='blue', label='MDR')
    plt.scatter(Y[class_0, 0], Y[class_0, 1], marker='o', s=45, linewidths=2.25, facecolors='none', color='green', label='non-MDR')


    plt.ylim(-80, 60)
    plt.xlim(-70, 70)
    plt.xticks(fontsize=26)
    plt.yticks(fontsize=26)
    plt.legend(prop={'size': 26}, markerscale=1.5,scatterpoints=1,handletextpad=0,fontsize=28, loc="best")
    plt.grid()
    plt.tight_layout()
    plt.savefig(name + '.pdf')
    
    return principalDf

# %%
# %matplotlib notebook
folders = ["S1"]

modelado = "TCK"

i = 0
print("==================================>" + folders[i] + "<=====================================")
y_train = pd.read_csv('../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + folders[i] + '/y_train_tensor.csv')
X_train = sio.loadmat('../Step1_TCK/data_generated_by_tck/S1/Ktrtr')
X_train = X_train['Ktrtr']


print(X_train.shape)
print(y_train.shape)

df_TSNE = plotTSNE(X_train, y_train, './Visual_2D/Figures/2_TCK', 20)
Admissiondboid_train = pd.read_csv("../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/" + folders[i] + "/Admissiondboid_train.csv")
Admissiondboid = []
for i in range(int(Admissiondboid_train.shape[0]/7)):
    Admissiondboid.append(Admissiondboid_train.loc[i*7][0])
    
Admissiondboid = pd.DataFrame(Admissiondboid, columns=["Admissiondboid"])
df_TSNE['Admissiondboid'] = Admissiondboid
# Out:
# ==================================>S1<=====================================
# (842, 842)
# (842, 1)

# %% [markdown]
# ### CVIs. sc over the original space

# %%
from sklearn.metrics import davies_bouldin_score, silhouette_score, calinski_harabasz_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import SpectralClustering
import matplotlib.ticker as ticker

results = {}

scaler = StandardScaler() 
df_TSNE_norm = scaler.fit_transform(df_TSNE[["pca1", "pca2"]])
df_TSNE_norm = pd.DataFrame(df_TSNE_norm, columns=["D1", "D2"])
data = df_TSNE_norm

j=4
for i in range(2,9):
    # n_init: number of times the k-means algorithm will be executed with different centroid seeds. 
    # max_iter: max number of iterations of the k-means algorithm for a single run.
    labels_sc = SpectralClustering(n_clusters=i, affinity='nearest_neighbors', n_neighbors=j, random_state=j).fit_predict(X_train)
    # Predicting the clusters
    db_index = davies_bouldin_score(data, labels_sc)
    results.update({i:db_index})

fig,axis = plt.subplots(1,1,figsize=(6,5))
fontsize=30
axis.plot(list(results.keys()),list(results.values()),'bo--',linewidth=2,alpha=1) 
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
axis.set_ylim(0.55, 1.2) 
plt.tight_layout()
axis.yaxis.grid(linestyle = 'dashed')  
axis.set_axisbelow(True)  
axis.yaxis.set_major_locator(ticker.MaxNLocator(nbins=7))
plt.savefig("./0_TCK/4_DaviesBoulding_tck.pdf")

# %%
from sklearn.metrics import davies_bouldin_score, silhouette_score, calinski_harabasz_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.cluster import SpectralClustering
import matplotlib.ticker as ticker

scaler = StandardScaler() 
df_TSNE_norm = scaler.fit_transform(df_TSNE[["pca1", "pca2"]])
df_TSNE_norm = pd.DataFrame(df_TSNE_norm, columns=["D1", "D2"])
data = df_TSNE_norm

j=5
for i in range(2,9):
    # n_init: number of times the k-means algorithm will be executed with different centroid seeds. 
    # max_iter: max number of iterations of the k-means algorithm for a single run.
    labels_sc = SpectralClustering(n_clusters=i, affinity='nearest_neighbors',n_neighbors=j,  random_state=j).fit_predict(X_train)
    # Predicting the clusters
    db_index = silhouette_score(data, labels_sc, random_state=j)
    results.update({i:db_index})

fig,axis = plt.subplots(1,1,figsize=(6,5))
axis.plot(list(results.keys()),list(results.values()),'bo--',linewidth=2,alpha=1)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
axis.yaxis.grid(linestyle = 'dashed')  
axis.set_axisbelow(True)  
axis.set_ylim(0.2, 0.6) 
axis.yaxis.set_major_locator(ticker.MaxNLocator(nbins=7))
plt.tight_layout()
plt.savefig("./0_TCK/4_Silhouette_tck.pdf")

# %% [markdown]
# ## Apply sc

# %%
from sklearn.cluster import SpectralClustering
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Set up data normalization
scaler = StandardScaler() 
df_TSNE_norm = scaler.fit_transform(df_TSNE[["pca1", "pca2"]])
df_TSNE_norm = pd.DataFrame(df_TSNE_norm, columns=["D1", "D2"])

# Create a figure with 4 subplots (for i = 2, 3, 4, 5)
f = plt.figure(figsize=(12,12))

for i in range(2, 6):
    sc = SpectralClustering(n_clusters=i, affinity='nearest_neighbors', n_neighbors=4, random_state=42).fit(X_train)
    ax = f.add_subplot(2, 2, i-1)
    
    if i == 2:
        index1 = np.where(sc.labels_ == 0)
        plt.scatter(df_TSNE_norm['D1'].iloc[index1[0]], df_TSNE_norm['D2'].iloc[index1[0]],
                    s=25, c=sc.labels_[index1], edgecolors="#00c3f8", marker='^')
        index2 = np.where(sc.labels_ == 1)
        plt.scatter(df_TSNE_norm['D1'].iloc[index2[0]], df_TSNE_norm['D2'].iloc[index2[0]],
                    s=25, c=sc.labels_[index2], edgecolors="#5ec962", marker='o')
        
    elif i == 3:
        index1 = np.where(sc.labels_ == 0)
        plt.scatter(df_TSNE_norm['D1'].iloc[index1[0]], df_TSNE_norm['D2'].iloc[index1[0]],
                    s=25, c=sc.labels_[index1], marker='^', edgecolors="#00c3f8")
        index2 = np.where(sc.labels_ == 1)
        plt.scatter(df_TSNE_norm['D1'].iloc[index2[0]], df_TSNE_norm['D2'].iloc[index2[0]],
                    s=25, c=sc.labels_[index2], edgecolors="#5ec962", marker='o')
        index3 = np.where(sc.labels_ == 2)
        plt.scatter(df_TSNE_norm['D1'].iloc[index3[0]], df_TSNE_norm['D2'].iloc[index3[0]],
                    s=25, c=sc.labels_[index3], edgecolors="black", marker='*')
        
    elif i == 4:
        index1 = np.where(sc.labels_ == 0)
        plt.scatter(df_TSNE_norm['D1'].iloc[index1[0]], df_TSNE_norm['D2'].iloc[index1[0]],
                    s=25, c=sc.labels_[index1], marker='^', edgecolors="#00c3f8")
        index2 = np.where(sc.labels_ == 1)
        plt.scatter(df_TSNE_norm['D1'].iloc[index2[0]], df_TSNE_norm['D2'].iloc[index2[0]],
                    s=25, c=sc.labels_[index2], edgecolors="#5ec962", marker='o')
        index3 = np.where(sc.labels_ == 2)
        plt.scatter(df_TSNE_norm['D1'].iloc[index3[0]], df_TSNE_norm['D2'].iloc[index3[0]],
                    s=25, c=sc.labels_[index3], edgecolors="black", marker='*')
        index4 = np.where(sc.labels_ == 3)
        plt.scatter(df_TSNE_norm['D1'].iloc[index4[0]], df_TSNE_norm['D2'].iloc[index4[0]],
                    s=25, c=sc.labels_[index4], edgecolors="#fde725", marker='s')
        
    elif i == 5:
        index1 = np.where(sc.labels_ == 0)
        plt.scatter(df_TSNE_norm['D1'].iloc[index1[0]], df_TSNE_norm['D2'].iloc[index1[0]],
                    s=25, c=sc.labels_[index1], marker='^', edgecolors="#00c3f8")
        index2 = np.where(sc.labels_ == 1)
        plt.scatter(df_TSNE_norm['D1'].iloc[index2[0]], df_TSNE_norm['D2'].iloc[index2[0]],
                    s=25, c=sc.labels_[index2], edgecolors="#5ec962", marker='o')
        index3 = np.where(sc.labels_ == 2)
        plt.scatter(df_TSNE_norm['D1'].iloc[index3[0]], df_TSNE_norm['D2'].iloc[index3[0]],
                    s=25, c=sc.labels_[index3], edgecolors="black", marker='*')
        index4 = np.where(sc.labels_ == 3)
        plt.scatter(df_TSNE_norm['D1'].iloc[index4[0]], df_TSNE_norm['D2'].iloc[index4[0]],
                    s=25, c=sc.labels_[index4], edgecolors="#fde725", marker='s')
        index5 = np.where(sc.labels_ == 4)
        plt.scatter(df_TSNE_norm['D1'].iloc[index5[0]], df_TSNE_norm['D2'].iloc[index5[0]],
                    s=25, c=sc.labels_[index5], edgecolors="violet", marker='D')
        df_TSNE_norm['labels'] = sc.labels_
    
    plt.xticks(fontsize=30, rotation=90)
    plt.yticks(fontsize=30)
    plt.grid()

# Create a single, horizontal legend below the subplots
import matplotlib.lines as mlines
legend_handles = [
    mlines.Line2D([], [], marker='^', color='w', markerfacecolor="#00c3f8", markeredgecolor="#00c3f8", markersize=10, label="C1"),
    mlines.Line2D([], [], marker='o', color='w', markerfacecolor="#5ec962", markeredgecolor="#5ec962", markersize=10, label="C2"),
    mlines.Line2D([], [], marker='*', color='w', markerfacecolor="black", markeredgecolor="black", markersize=10, label="C3"),
    mlines.Line2D([], [], marker='s', color='w', markerfacecolor="#fde725", markeredgecolor="#fde725", markersize=10, label="C4"),
    mlines.Line2D([], [], marker='D', color='w', markerfacecolor="violet", markeredgecolor="violet", markersize=10, label="C5")
]

f.legend(handles=legend_handles, loc='lower center', ncol=5, fontsize=30)
plt.tight_layout(rect=[0, 0.08, 1, 1])
plt.savefig("./0_TCK/3_spectralclustering_tck.pdf")
plt.show()

# %%
df_TSNE_norm["Admissiondboid"] = df_TSNE[["Admissiondboid"]]
df_TSNE_norm.labels.value_counts()
df_TSNE_norm
# Out:
#            D1        D2  labels       Admissiondboid
# 0    0.795758  0.533246       1  4587163021305236556
# 1    0.791224  0.261529       0  4678128168113384556
# 2   -2.379999  0.083331       4  4591376991402172556
# 3   -0.114119 -1.695340       3  4444811933250193556
# 4   -1.942835 -1.041140       2  4590697252690172556
# ..        ...       ...     ...                  ...
# 837  0.666212  1.111956       1  4483887072348232556
# 838  0.583409 -0.811258       0  4357674703981004556
# 839  0.082684 -1.708603       3  4613004308355172556
# 840  1.191058 -0.114146       0  4502903024299210556
# 841 -0.610368  1.461562       1  4486753242683172556
#
# [842 rows x 4 columns]

# %%
df_TSNE_norm.labels.value_counts()
# Out:
# 1    326
# 0    281
# 2    107
# 3     81
# 4     47
# Name: labels, dtype: int64

# %%
df_TSNE_norm.to_csv("./0_TCK/clusters_bestROCAUC_TCK_5clusteres.csv", index=False)
