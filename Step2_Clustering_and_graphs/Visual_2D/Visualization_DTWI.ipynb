# %%
import numpy as np
import pandas as pd

from sklearn import manifold
import matplotlib.pyplot as plt
import matplotlib 

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import davies_bouldin_score, silhouette_score
from sklearn.cluster import SpectralClustering

import datetime
from datetime import timedelta

import utils

# %% [markdown]
# ## DTWI + AE

# %% [markdown]
# ### Train set 0

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "AE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 0

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_AE_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=True, path='./Figures/2_DTWI_AE.pdf')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S1<=====================================
# (842, 300)
# (842, 1)

# %% [markdown]
# ### Train set 1

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "AE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 1

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_AE_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S2<=====================================
# (852, 400)
# (852, 1)

# %% [markdown]
# ### Train set 2

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "AE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 2

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_AE_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S3<=====================================
# (856, 400)
# (856, 1)

# %% [markdown]
# ### Train set 3

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "AE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 3

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_AE_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S4<=====================================
# (866, 425)
# (866, 1)

# %% [markdown]
# ### Train set 4

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "AE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 4

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_AE_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S5<=====================================
# (846, 450)
# (846, 1)

# %% [markdown]
# ## TCK + DAE

# %% [markdown]
# ### Train set 0

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "DAE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 0

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_DAE_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S1<=====================================
# (842, 350)
# (842, 1)

# %% [markdown]
# ### Train set 1

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "DAE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 1

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_DAE_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S2<=====================================
# (852, 250)
# (852, 1)

# %% [markdown]
# ### Train set 2

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "DAE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 2

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_DAE_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S3<=====================================
# (856, 450)
# (856, 1)

# %% [markdown]
# ### Train set 3

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "DAE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 3

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_DAE_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S4<=====================================
# (866, 375)
# (866, 1)

# %% [markdown]
# ### Train set 4

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "DAE"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 4

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_DAE_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S5<=====================================
# (846, 350)
# (846, 1)

# %% [markdown]
# ## TCK + PCA

# %% [markdown]
# ### Train set 0

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "PCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 0

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_PCA_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S1<=====================================
# (842, 19)
# (842, 1)

# %% [markdown]
# ### Train set 1

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "PCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 1

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_PCA_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S2<=====================================
# (852, 19)
# (852, 1)

# %% [markdown]
# ### Train set 2

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "PCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 2

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_PCA_' + carpetas[i] + '.csv')
print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S3<=====================================
# (856, 19)
# (856, 1)

# %% [markdown]
# ### Train set 3

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "PCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 3

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_PCA_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S4<=====================================
# (866, 20)
# (866, 1)

# %% [markdown]
# ### Train set 4

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "PCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 4

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_PCA_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S5<=====================================
# (846, 19)
# (846, 1)

# %% [markdown]
# ## DTWI + KPCA

# %% [markdown]
# ### Train set 1

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "KPCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 0

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_KPCA_' + carpetas[i] + '.csv')

print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S1<=====================================
# (842, 30)
# (842, 1)

# %% [markdown]
# ### Train set 1

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "KPCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 1

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_KPCA_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S2<=====================================
# (852, 30)
# (852, 1)

# %% [markdown]
# ### Train set 2

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "KPCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 2

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_KPCA_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S3<=====================================
# (856, 30)
# (856, 1)

# %% [markdown]
# ### Train set 3

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "KPCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 3

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_KPCA_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S4<=====================================
# (866, 30)
# (866, 1)

# %% [markdown]
# ### Train set 4

# %%
carpetas = ["S1", "S2", "S3", "S4", "S5"]
method = "KPCA"
analysis_method = "DTW_I"

more_analysis = False

##### Select the set of data to analyze
i = 4

print("==================================>" + carpetas[i] + "<=====================================")
####### begin load data
y_train = pd.read_csv('../../df_to_load/DataToPaperAndTFM_Mod1/Subconjuntos_3D/' + carpetas[i] + '/y_train_tensor.csv')
X_train = pd.read_csv('../../Step1_DTW/' + '1_Clasifications_models/' + 'data_reduced/' + analysis_method + '/' + method + '/X_train_Norm_KPCA_' + carpetas[i] + '.csv')


print(X_train.shape)
print(y_train.shape)
#### end load data

###### begin df_TSNE
df_TSNE = utils.plotTSNE(X_train, y_train, 20, savefig=False, path='')
# get admissiondboid
df_TSNE = utils.add_Adb(df_TSNE, carpetas[i])
##### end df_TSNE

if more_analysis:
    ##### CVIs to get the number of clusters
    results = utils.f_davies_bouldin_score(df_TSNE, X_train)
    number_of_clusters_DB = min(results, key=results.get)

    results = utils.f_silhouette_score(df_TSNE, X_train)
    number_of_clusters_SC = max(results, key=results.get)

    if number_of_clusters_DB == number_of_clusters_SC:
        n_cluster = number_of_clusters_SC
    else:
        print("=======> Number of different clusters")

    ##### end CVIs

    ##### add labels to TSNE
    df_TSNE_with_sc_labels = utils.f_sc(df_TSNE, X_train, n_cluster)
    ##### number of unique labels
    num_labels = len(np.unique(df_TSNE_with_sc_labels.labels))

    ###### begin cluster analysis
    for i in range(num_labels):
        print(" <============ Cluster analysis ============>")
        utils.analysisCluster(df_TSNE_with_sc_labels, i, group)
    # ###### end cluster analysis
# Out:
# ==================================>S5<=====================================
# (846, 30)
# (846, 1)
